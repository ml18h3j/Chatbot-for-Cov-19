# %%
import re
import time
from nltk.tokenize import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
import os
import tqdm
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# Read File

# %%
file_name = 'WHO_FAQ.csv'
df = pd.read_csv(file_name)
df
# Out:
#                                               Context  \
# 0                  What are the symptoms of COVID-19?
# 1                  What are the symptoms of COVID-19?
# 2                  What are the symptoms of COVID-19?
# 3                  What are the symptoms of COVID-19?
# 4                           How does COVID-19 spread?
# 5                           How does COVID-19 spread?
# 6   Can the virus that causes COVID-19 be transmit...
# 7   Can CoVID-19 be caught from a person who has n...
# 8   Can CoVID-19 be caught from a person who has n...
# 9   Can I catch COVID-19 from the feces of someone...
# 10  What can I do to protect myself and prevent th...
# 11  What can I do to protect myself and prevent th...
# 12  What can I do to protect myself and prevent th...
# 13  What can I do to protect myself and prevent th...
# 14  What can I do to protect myself and prevent th...
# 15  What can I do to protect myself and prevent th...
# 16  What can I do to protect myself and prevent th...
# 17  What can I do to protect myself andProtection ...
# 18  Protection measures for persons who are in or ...
# 19                 How likely am I to catch COVID-19?
# 20                 How likely am I to catch COVID-19?
# 21                 How likely am I to catch COVID-19?
# 22                      Should I worry about COVID-19
# 23                      Should I worry about COVID-19
# 24       Who is at risk of developing severe illness?
# 25  Are antibiotics effective in preventing or tre...
# 26  Are antibiotics effective in preventing or tre...
# 27  Are there any medicines or therapies that can ...
# 28  Are there any medicines or therapies that can ...
# 29  Is there a vaccine, drug or treatment for COVI...
# ..                                                ...
# 54                 Is there anything I should not do?
# 55                 Is there anything I should not do?
# 56              Is the source causing COVID-19 known?
# 57  How did the first human SARS-CoV-2 infections ...
# 58  How did the first human SARS-CoV-2 infections ...
# 59  How did the first human SARS-CoV-2 infections ...
# 60                              Is COVID-19 airborne?
# 61   Are pregnant women at higher risk from COVID-19?
# 62   Are pregnant women at higher risk from COVID-19?
# 63  I'm pregnant. How can I protect myself against...
# 64  I'm pregnant. How can I protect myself against...
# 65      Should pregnant women be tested for COVID-19?
# 66  Can COVID-19 be passed from a woman to her unb...
# 67  What care should be available during pregnancy...
# 68  Do pregnant women with suspected or confirmed ...
# 69                Can women with COVID-19 breastfeed?
# 70  Can I touch and hold my newborn baby if I have...
# 71    How are COVID-19 and influenza viruses similar?
# 72    How are COVID-19 and influenza viruses similar?
# 73  How are COVID-19 and influenza viruses different?
# 74  How are COVID-19 and influenza viruses different?
# 75  How are COVID-19 and influenza viruses different?
# 76  What medical interventions are available for C...
# 77  Are smokers and tobacco users at higher risk o...
# 78  Are smokers and tobacco users at higher risk o...
# 79  How large does a meeting or event need to be i...
# 80  How large does a meeting or event need to be i...
# 81  Does WHO recommend that all international mass...
# 82                               What is coronavirus?
# 83                                  What is COVID-19?
#
#                                                Answer
# 0   The most common symptoms of COVID-19 are fever...
# 1   Some people become infected but don鈥檛 develop ...
# 2   Around 1 out of every 6 people who gets COVID-...
# 3   Older people, and those with underlying medica...
# 4   People can catch COVID-19 from others who have...
# 5   People can also catch COVID-19 if they breathe...
# 6   Studies to date suggest that the virus that ca...
# 7   The main way the disease spreads is through re...
# 8   Many people with COVID-19 experience only mild...
# 9   The risk of catching COVID-19 from the feces o...
# 10  Regularly and thoroughly clean your hands with...
# 11  Maintain at least 1 metre (3 feet) distance be...
# 12               Avoid touching eyes, nose and mouth.
# 13  Make sure you, and the people around you, foll...
# 14  Stay home if you feel unwell. If you have a fe...
# 15  If possible, avoid traveling to places ?鈥?espe...
# 16  Keep up to date on the latest COVID-19 hotspot...
# 17  Self-isolate by staying at home if you begin t...
# 18  If you develop fever, cough and difficulty bre...
# 19  The risk depends on where you ?are - and more ...
# 20  For most people in most locations the risk of ...
# 21  COVID-19 outbreaks can be contained and transm...
# 22  Illness due to COVID-19 infection is generally...
# 23  We can channel our concerns into actions to pr...
# 24  While we are still learning about how COVID-20...
# 25  No. Antibiotics do not work against viruses, t...
# 26  Antibiotics should not be used as a means of p...
# 27  While some western, traditional or home remedi...
# 28  WHO does not recommend self-medication with an...
# 29  Not yet. To date, there is no vaccine and no s...
# ..                                                ...
# 54                             Wearing multiple masks
# 55                                 Taking antibiotics
# 56  Currently, the source of SARS-CoV-2, the coron...
# 57  The first human cases of COVID-19 were identif...
# 58  SARS-CoV, the virus which caused the SARS outb...
# 59  Until the source of this virus is identified a...
# 60  The virus that causes COVID-19 is mainly trans...
# 61  At present there is no evidence that they are ...
# 62  due to changes in their bodies and immune syst...
# 63  Pregnant women should take the same precaution...
# 64  Pregnant women and women who have recently del...
# 65  Testing protocols and eligibility vary dependi...
# 66  We still do not know if a pregnant woman with ...
# 67  All pregnant women, including those with confi...
# 68  No. WHO advice is that caesarean sections shou...
# 69  Yes. Women with COVID-19 can breastfeed if the...
# 70  Yes. Close contact and early, exclusive breast...
# 71  COVID-19 and influenza viruses have a similar ...
# 72  Both viruses are transmitted by contact, dropl...
# 73  The speed of transmission is an important poin...
# 74  Those most at risk for severe influenza infect...
# 75  Mortality for COVID-19 appears higher than for...
# 76  While there are a number of therapeutics curre...
# 77  Smokers are likely to be more vulnerable to CO...
# 78  Smoking products such as water pipes often inv...
# 79  High profile international sporting events suc...
# 80  An event counts as a 鈥渕ass gatherings鈥?if the ...
# 81  No. As each international mass gathering is di...
# 82  COVID-19 is the infectious disease caused by t...
# 83  COVID-19 is the infectious disease caused by t...
#
# [84 rows x 2 columns]

# %% [markdown]
# 取问题作为单独的list(用来训练similarity模型)

# %%
questions_raw = list(set(df['Context']))
questions_raw[:5]
# Out:
# ['Are there any medicines or therapies that can prevent or cure COVID-19?',
#  'Are smokers and tobacco users at higher risk of COVID-19 infection?',
#  'Is COVID-19 the same as SARS?',
#  'Who is at risk of developing severe illness?',
#  'What medical interventions are available for COVID-19 and influenza viruses?']

# %% [markdown]
# 创建问题-答案序号对，以及答案序号-答案对。
# 这样处理的话，当用户键入问题时，会定位到问题库(也就是csv中的内容)相应的问题，然后通过问题随机选一个相应的答案序号，再通过答案序号定位所需答案。
# 保存两个字典。

# %%
qa_dic = {}
num_a_dic = {}
for idx, row in df.iterrows():
    num_a_dic[idx] = row['Answer']
    context = row['Context']
    if context not in qa_dic:
        qa_dic[context] = []
    qa_dic[context].append(idx)
    
# save
with open('qa_dic.pickle', 'wb') as f:
    pickle.dump(qa_dic, f)
with open('num_a_dic.pickle', 'wb') as f:
    pickle.dump(num_a_dic, f)
qa_dic, num_a_dic
# Out:
# ({'What are the symptoms of COVID-19?': [0, 1, 2, 3],
#   'How does COVID-19 spread?': [4, 5],
#   'Can the virus that causes COVID-19 be transmitted through the air?': [6],
#   'Can CoVID-19 be caught from a person who has no symptoms?': [7, 8],
#   'Can I catch COVID-19 from the feces of someone with the disease?': [9],
#   'What can I do to protect myself and prevent the spread of disease?': [10,
#    11,
#    12,
#    13,
#    14,
#    15,
#    16],
#   'What can I do to protect myself andProtection measures for persons who are in or have recently visited (past 14 days) areas where COVID-19 is spreading prevent the spread of disease?': [17],
#   'Protection measures for persons who are in or have recently visited (past 14 days) areas where COVID-19 is spreading': [18],
#   'How likely am I to catch COVID-19?': [19, 20, 21],
#   'Should I worry about COVID-19': [22, 23],
#   'Who is at risk of developing severe illness?': [24],
#   'Are antibiotics effective in preventing or treating the COVID-19?': [25,
#    26],
#   'Are there any medicines or therapies that can prevent or cure COVID-19?': [27,
#    28],
#   'Is there a vaccine, drug or treatment for COVID-19?': [29, 30, 31, 32],
#   'Is COVID-19 the same as SARS?': [33, 34],
#   'Should I wear a mask to protect myself': [35, 36, 37],
#   'How to put on, use, take off and dispose of a mask?': [38, 39],
#   'How long is the incubation period for COVID-19?': [40, 41],
#   'Can humans be infected with the COVID-19 from an animal source?': [42,
#    43,
#    44,
#    45,
#    46],
#   'Can I catch COVID-19 from my pet?': [47, 48],
#   'How long does the virus survive on surfaces?': [49, 50, 51],
#   'Is it safe to receive a package from any area where COVID-19 has been reported?': [52],
#   'Is there anything I should not do?': [53, 54, 55],
#   'Is the source causing COVID-19 known?': [56],
#   'How did the first human SARS-CoV-2 infections occur?': [57, 58, 59],
#   'Is COVID-19 airborne?': [60],
#   'Are pregnant women at higher risk from COVID-19?': [61, 62],
#   "I'm pregnant. How can I protect myself against COVID-19?": [63, 64],
#   'Should pregnant women be tested for COVID-19?': [65],
#   'Can COVID-19 be passed from a woman to her unborn baby?': [66],
#   'What care should be available during pregnancy and childbirth?': [67],
#   'Do pregnant women with suspected or confirmed COVID-19 need to give birth by ceasarean section?': [68],
#   'Can women with COVID-19 breastfeed?': [69],
#   'Can I touch and hold my newborn baby if I have COVID-19?': [70],
#   'How are COVID-19 and influenza viruses similar?': [71, 72],
#   'How are COVID-19 and influenza viruses different?': [73, 74, 75],
#   'What medical interventions are available for COVID-19 and influenza viruses?': [76],
#   'Are smokers and tobacco users at higher risk of COVID-19 infection?': [77,
#    78],
#   'How large does a meeting or event need to be in order to be a 鈥渕ass gathering鈥?': [79,
#    80],
#   'Does WHO recommend that all international mass gatherings be cancelled because of COVID-19?': [81],
#   'What is coronavirus?': [82],
#   'What is COVID-19?': [83]},
#  {0: 'The most common symptoms of COVID-19 are fever, tiredness, and dry cough. Some patients may have aches and pains, nasal congestion, runny nose, sore throat or diarrhea. These symptoms are usually mild and begin gradually.',
#   1: "Some people become infected but don鈥檛 develop any symptoms and don't feel unwell. Most people (about 80%) recover from the disease without needing special treatment.",
#   2: 'Around 1 out of every 6 people who gets COVID-19 becomes seriously ill and develops difficulty breathing.?',
#   3: 'Older people, and those with underlying medical problems like high blood pressure, heart problems or diabetes, are more likely to develop serious illness. People with fever, cough and difficulty breathing should seek medical attention.',
#   4: 'People can catch COVID-19 from others who have the virus. The disease can spread from person to person through small droplets from the nose or mouth which are spread when a person with COVID-19 coughs or exhales.?',
#   5: 'People can also catch COVID-19 if they breathe in droplets from a person with COVID-19 who coughs out or exhales droplets. This is why it is important to stay more than 1 meter (3 feet) away from a person who is sick.',
#   6: 'Studies to date suggest that the virus that causes COVID-19 is mainly transmitted through contact with respiratory droplets rather than through the air.?',
#   7: 'The main way the disease spreads is through respiratory droplets expelled by someone who is coughing. The risk of catching COVID-19 from someone with no symptoms at all is very low.',
#   8: 'Many people with COVID-19 experience only mild symptoms. This is particularly true at the early stages of the disease. It is therefore possible to catch COVID-19 from someone who has, for example, just a mild cough and does not feel ill. ',
#   9: 'The risk of catching COVID-19 from the feces of an infected person appears to be low. While initial investigations suggest the virus may be present in feces in some cases, spread through this route is not a main feature of the outbreak. ',
#   10: 'Regularly and thoroughly clean your hands with an alcohol-based hand rub or wash them with soap and water.',
#   11: 'Maintain at least 1 metre (3 feet) distance between yourself and anyone who is coughing or sneezing.',
#   12: 'Avoid touching eyes, nose and mouth.',
#   13: 'Make sure you, and the people around you, follow good respiratory hygiene. This means covering your mouth and nose with your bent elbow or tissue when you cough or sneeze. Then dispose of the used tissue immediately.',
#   14: 'Stay home if you feel unwell. If you have a fever, cough and difficulty breathing, seek medical attention and call in advance. Follow the directions of your local health authority.',
#   15: 'If possible, avoid traveling to places ?鈥?especially if you are an older person or have diabetes, heart or lung disease.',
#   16: 'Keep up to date on the latest COVID-19 hotspots (cities or local areas where COVID-19 is spreading widely).',
#   17: 'Self-isolate by staying at home if you begin to feel unwell, even with mild symptoms such as headache, low grade fever (37.3 C or above) and slight runny nose, until you recover.',
#   18: 'If you develop fever, cough and difficulty breathing, seek medical advice promptly as this may be due to a respiratory infection or other serious condition. Call in advance and tell your provider of any recent travel or contact with travelers.',
#   19: 'The risk depends on where you ?are - and more specifically, whether there is a COVID-19 outbreak unfolding there.',
#   20: 'For most people in most locations the risk of catching COVID-19 is still low. However, there are now places around the world (cities or areas) where the disease is spreading. For people living in, or visiting, these areas the risk of catching COVID-19 is higher.',
#   21: 'COVID-19 outbreaks can be contained and transmission stopped, as has been shown in China and some other countries. Unfortunately, new outbreaks can emerge rapidly. It鈥檚 important to be aware of the situation where you are or intend to go.',
#   22: 'Illness due to COVID-19 infection is generally mild, especially for children and young adults. However, it can cause serious illness: about 1 in every 5 people who catch it need hospital care.',
#   23: 'We can channel our concerns into actions to protect ourselves, our loved ones and our communities.',
#   24: 'While we are still learning about how COVID-2019 affects people, older persons and persons with pre-existing medical conditions (such as high blood pressure, heart disease, lung disease, cancer or diabetes)  appear to develop serious illness more often than others. ',
#   25: 'No. Antibiotics do not work against viruses, they only work on bacterial infections. COVID-19 is caused by a virus, so antibiotics do not work.?',
#   26: 'Antibiotics should not be used as a means of prevention or treatment of COVID-19. They should only be used as directed by a physician to treat a bacterial infection.?',
#   27: 'While some western, traditional or home remedies may provide comfort and alleviate symptoms of COVID-19, there is no evidence that current medicine can prevent or cure the disease.?',
#   28: 'WHO does not recommend self-medication with any medicines, including antibiotics, as a prevention or cure for COVID-19.',
#   29: 'Not yet. To date, there is no vaccine and no specific antiviral medicine to prevent or treat COVID-2019.?',
#   30: 'Those affected should receive care to relieve symptoms. People with serious illness should be hospitalized. Most patients recover thanks to supportive care.',
#   31: 'Possible vaccines and some specific drug treatments are under investigation. They are being tested through clinical trials. WHO is coordinating efforts to develop vaccines and medicines to prevent and treat COVID-19.',
#   32: 'The most effective ways to protect yourself and others against COVID-19 are to frequently clean your hands, cover your cough with the bend of elbow or tissue, and maintain a distance of at least 1 meter (3 feet) from people who are coughing or sneezing.',
#   33: 'No. The virus that causes COVID-19 and the one that caused the outbreak of Severe Acute Respiratory Syndrome (SARS) in 2003 are related to each other genetically, but the diseases they cause are quite different.',
#   34: 'SARS was more deadly but much less infectious than COVID-19. There have been no outbreaks of SARS anywhere in the world since 2003.',
#   35: 'Only wear a mask if you are ill with COVID-19 symptoms (especially coughing) or looking after someone who may have COVID-19. Disposable face mask can only be used once.',
#   36: 'If you are not ill or looking after someone who is ill then you are wasting a mask.?',
#   37: 'There is a world-wide shortage of masks, so WHO urges people to use masks wisely.',
#   38: 'Remember, a mask should only be used by health workers, care takers, and individuals with respiratory symptoms, such as fever and cough.',
#   39: 'Before touching the mask, clean hands with an alcohol-based hand rub or soap and water',
#   40: 'The 鈥渋ncubation period鈥?means the time between catching the virus and beginning to have symptoms of the disease.',
#   41: 'Most estimates of the incubation period for COVID-19 range from 1-14 days, most commonly around five days. These estimates will be updated as more data become available.',
#   42: 'Coronaviruses are a large family of viruses that are common in animals. Occasionally, people get infected with these viruses which may then spread to other people.',
#   43: 'SARS-CoV was associated with civet cats and MERS-CoV is transmitted by dromedary camels. ',
#   44: 'Possible animal sources of COVID-19 have not yet been confirmed. ?',
#   45: 'To protect yourself, such as when visiting live animal markets, avoid direct contact with animals and surfaces in contact with animals.',
#   46: 'Handle raw meat, milk or animal organs with care to avoid contamination of uncooked foods and avoid consuming raw or undercooked animal products.',
#   47: 'While there has been?one instance of a dog being infected in Hong Kong, to?date, there is no evidence that a dog, cat or any pet can transmit COVID-19.',
#   48: 'COVID-19 is mainly spread through droplets produced when an infected person coughs, sneezes, or speaks.',
#   49: 'It is not certain how long the virus that causes COVID-19 survives on surfaces, but it seems to behave like other coronaviruses.',
#   50: 'Studies suggest that coronaviruses (including preliminary information on the COVID-19 virus) may persist on surfaces for a few hours or up to several days. This may vary under different conditions (e.g. type of surface, temperature or humidity of the environment).',
#   51: 'If you think a surface may be infected, clean it with simple disinfectant to kill the virus and protect yourself and others.',
#   52: 'Yes. The likelihood of an infected person contaminating commercial goods is low and the risk of catching the virus that causes COVID-19 from a package that has been moved, travelled, and exposed to different conditions and temperature is also low.?',
#   53: 'Smoking',
#   54: 'Wearing multiple masks',
#   55: 'Taking antibiotics',
#   56: 'Currently, the source of SARS-CoV-2, the coronavirus (CoV) causing COVID-19 is unknown.',
#   57: 'The first human cases of COVID-19 were identified in Wuhan City, China in December 2019.',
#   58: 'SARS-CoV, the virus which caused the SARS outbreak in 2003, jumped from an animal reservoir (civet cats, a farmed wild animal) to humans and then spread between humans.?',
#   59: 'Until the source of this virus is identified and controlled, there is a risk of reintroduction of the virus in the human population and the risk of new outbreaks like the ones we are currently experiencing.',
#   60: 'The virus that causes COVID-19 is mainly transmitted through droplets generated when an infected person coughs, sneezes, or speaks. These droplets are too heavy to hang in the air. They quickly fall on floors or surfaces. ',
#   61: 'At present there is no evidence that they are at higher risk of severe illness than the general population.',
#   62: 'due to changes in their bodies and immune systems, we know that pregnant women can be badly affected by some respiratory infections. It is therefore important that they take precautions to protect themselves against COVID-19, and report possible symptoms (including fever, cough or difficulty breathing) to their healthcare provider.',
#   63: 'Pregnant women should take the same precautions to avoid COVID-19 infection as other people.',
#   64: 'Pregnant women and women who have recently delivered 鈥?including those affected by COVID-19 - should attend their routine care appointments.?',
#   65: 'Testing protocols and eligibility vary depending on where you live.',
#   66: 'We still do not know if a pregnant woman with COVID-19 can pass the virus to her foetus or baby during pregnancy or delivery. To date, the virus has not been found in samples of amniotic fluid or breastmilk.',
#   67: 'All pregnant women, including those with confirmed or suspected COVID-19 infections, have the right to high quality care before, during and after childbirth.?',
#   68: 'No. WHO advice is that caesarean sections should only be performed when medically justified.',
#   69: 'Yes. Women with COVID-19 can breastfeed if they wish to do so.',
#   70: 'Yes. Close contact and early, exclusive breastfeeding helps a baby to thrive. ',
#   71: 'COVID-19 and influenza viruses have a similar disease presentation. That is, they both cause respiratory disease, which presents as a wide range of illness from asymptomatic or mild through to severe disease and death.',
#   72: 'Both viruses are transmitted by contact, droplets and fomites.',
#   73: 'The speed of transmission is an important point of difference between the two viruses. Influenza has a shorter median incubation period (the time from infection to appearance of symptoms) and a shorter serial interval (the time between successive cases) than COVID-19 virus.',
#   74: 'Those most at risk for severe influenza infection are children, pregnant women, elderly, those with underlying chronic medical conditions and those who are immunosuppressed.',
#   75: 'Mortality for COVID-19 appears higher than for influenza, especially seasonal influenza.',
#   76: 'While there are a number of therapeutics currently in clinical trials in China and more than 20 vaccines in development for COVID-19, there are currently no licensed vaccines or therapeutics for COVID-19.',
#   77: 'Smokers are likely to be more vulnerable to COVID-19 as the act of smoking means that fingers (and possibly contaminated cigarettes) are in contact with lips which increases the possibility of transmission of virus from hand to mouth.',
#   78: 'Smoking products such as water pipes often involve the sharing of mouth pieces and hoses, which could facilitate the transmission of COVID-19 in communal and social settings.',
#   79: 'High profile international sporting events such as the Olympics or World Cups as well as international religious events such as the Hajj count as mass gatherings.',
#   80: 'An event counts as a 鈥渕ass gatherings鈥?if the number of people it brings together is so large that it has the potential to strain the planning and response resources of the health system in the community where it takes place.?',
#   81: 'No. As each international mass gathering is different, the factors to consider when determining if the event should be cancelled may also differ.?',
#   82: 'COVID-19 is the infectious disease caused by the most recently discovered coronavirus. This new virus and disease were unknown before the outbreak began in Wuhan, China, in December 2019.?COVID-19 is now a pandemic affecting many countries globally.',
#   83: 'COVID-19 is the infectious disease caused by the most recently discovered coronavirus. This new virus and disease were unknown before the outbreak began in Wuhan, China, in December 2019.?COVID-19 is now a pandemic affecting many countries globally.'})

# %% [markdown]
# 创建完整的文本list(用来预训练词向量)

# %%
alltext_raw = list(df['Context']) + list(df['Answer'])
alltext_raw = list(set(alltext_raw))
len(alltext_raw), alltext_raw[:3]
# Out:
# (125,
#  ['Avoid touching eyes, nose and mouth.',
#   'At present there is no evidence that they are at higher risk of severe illness than the general population.',
#   'Are smokers and tobacco users at higher risk of COVID-19 infection?'])

# %% [markdown]
# ### Preprocessing sentences
# 分为三步。
# 1. 分词+小写化+stemming。英文用空格分隔单词，之间利用空格分词；所有字母均小写化，以统一词汇；stemming词干提取，抽取词的词干形式，使不同形式但表意一致的单词表现为同一形式。
# 2. 使用nltk库删除停用词。去除停用词是为了让模型忽略那些通用的词汇，而这些通用词汇通常对句子表意没有关联。
# 3. 填充句子，使所有句子长度相同。创建单词词典word_to_token(单词对应序号),token_to_word(序号对应单词)。

# %%
# Get stopwords list & punctuations list
from nltk.corpus import stopwords
stopwords = stopwords.words('english')

# punctuations
english_punctuations = [',', '--', '<', '>', '.', ':', ';', '?', '(', ')', '[', ']', '&', '\'\'', '``', '!', '*', '@', '#', '$', '%']
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# (split words + lowercase + stem) + remove stopwords
stemmer = LancasterStemmer()

def preprocess_sen(sen):
    # split words + stem
    wordlist = [stemmer.stem(word.lower()) for word in word_tokenize(q)]
    # wordlist = data['review_content'].lower().split()

    # remove stopwords
    outlist = []  # 每个句子输出结果 - list
    for word in wordlist:
        if word not in stopwords and word not in english_punctuations:
            if word != '\t' and word != '\n' and word != ' ':
                outlist.append(word)
    return outlist

questions = []    # all questions set
for q in tqdm.tqdm(questions_raw):
    outlist = preprocess_sen(q)
    questions.append(outlist)
    
#save
with open('questions.pickle', 'wb') as f:
    pickle.dump(questions, f)
with open('questionsraw.pickle', 'wb') as f:
    pickle.dump(questions_raw, f)


alltext = []
for q in tqdm.tqdm(alltext_raw):
    outlist = preprocess_sen(q)
    alltext.append(outlist)
questions_raw[:5], questions[:5]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 915.49it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 125/125 [00:00<00:00, 1440.67it/s]
# (['Are there any medicines or therapies that can prevent or cure COVID-19?',
#   'Are smokers and tobacco users at higher risk of COVID-19 infection?',
#   'Is COVID-19 the same as SARS?',
#   'Who is at risk of developing severe illness?',
#   'What medical interventions are available for COVID-19 and influenza viruses?'],
#  [['ar', 'ther', 'medicin', 'therapy', 'prev', 'cur', 'covid-19'],
#   ['ar', 'smok', 'tobacco', 'us', 'high', 'risk', 'covid-19', 'infect'],
#   ['covid-19', 'sam', 'sar'],
#   ['risk', 'develop', 'sev', 'il'],
#   ['med', 'interv', 'ar', 'avail', 'covid-19', 'influenz', 'virus']])

# %%
alltext_words = sum(alltext, [])
longest_length = max([len(_) for _ in questions])

# 取无重复的所有词的list
wordlist = list(set(alltext_words))
wordlist.append("<pad>")    # to fill in the blank
wordlist.append("<unk>")    # to represent the unknown word

# save wordlist
with open('WordList.txt', 'w', encoding='utf8') as f:
    for word in wordlist:
        f.write(word)
        f.write('\n')

# %%
# Fill in the sentences to max length
padded_questions = []
for q in questions:
    if len(q) < longest_length:
        q.extend(["<pad>"] * (longest_length - len(q)))
    padded_questions.append(q)
padded_questions[:2]
# Out:
# [['ar',
#   'ther',
#   'medicin',
#   'therapy',
#   'prev',
#   'cur',
#   'covid-19',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>'],
#  ['ar',
#   'smok',
#   'tobacco',
#   'us',
#   'high',
#   'risk',
#   'covid-19',
#   'infect',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>',
#   '<pad>']]

# %%
#creare word<->token dic
# word -> token
word_to_token = {word: token for token, word in enumerate(wordlist)}
# token -> word
token_to_word = {token: word for word, token in word_to_token.items()}
word_to_token
# Out:
# {'adult': 0,
#  '14': 1,
#  'prev': 2,
#  '2019': 3,
#  'therapy': 4,
#  'interv': 5,
#  'ev': 6,
#  'jump': 7,
#  'caus': 8,
#  'c': 9,
#  'season': 10,
#  'throat': 11,
#  'howev': 12,
#  'mask': 13,
#  'dog': 14,
#  'anywh': 15,
#  'bend': 16,
#  'wash': 17,
#  'milk': 18,
#  'day': 19,
#  'right': 20,
#  'tissu': 21,
#  'kong': 22,
#  'urg': 23,
#  'fev': 24,
#  '2003': 25,
#  '6': 26,
#  'recov': 27,
#  'chin': 28,
#  'think': 29,
#  'wid': 30,
#  'inst': 31,
#  '鈥': 32,
#  'wild': 33,
#  'high': 34,
#  'first': 35,
#  'dat': 36,
#  'suggest': 37,
#  'pet': 38,
#  'hold': 39,
#  'respons': 40,
#  'period鈥': 41,
#  'rout': 42,
#  'food': 43,
#  'anyth': 44,
#  'discov': 45,
#  'reliev': 46,
#  'look': 47,
#  'poss': 48,
#  'aw': 49,
#  'direct': 50,
#  'unknown': 51,
#  'contamin': 52,
#  'breastmilk': 53,
#  'cas': 54,
#  'dist': 55,
#  'slight': 56,
#  'occ': 57,
#  'grad': 58,
#  'cough': 59,
#  'situ': 60,
#  'fiv': 61,
#  'piec': 62,
#  'tradit': 63,
#  'rapid': 64,
#  'much': 65,
#  'put': 66,
#  'unwel': 67,
#  'disinfect': 68,
#  'hav': 69,
#  'ourselv': 70,
#  'sneez': 71,
#  'city': 72,
#  'common': 73,
#  'therapeut': 74,
#  'diff': 75,
#  'attend': 76,
#  'exclud': 77,
#  'frequ': 78,
#  'expery': 79,
#  'expel': 80,
#  'fact': 81,
#  'sampl': 82,
#  'touch': 83,
#  'covid-2019': 84,
#  'tir': 85,
#  'good': 86,
#  'world-wide': 87,
#  'immun': 88,
#  'mean': 89,
#  'wher': 90,
#  'affect': 91,
#  'aft': 92,
#  'thi': 93,
#  'famy': 94,
#  'sect': 95,
#  'area': 96,
#  'worry': 97,
#  'particul': 98,
#  'olymp': 99,
#  'mild': 100,
#  'prompt': 101,
#  'quick': 102,
#  'som': 103,
#  'country': 104,
#  'due': 105,
#  'exh': 106,
#  'ser': 107,
#  'protect': 108,
#  'plan': 109,
#  'work': 110,
#  'coronavirus': 111,
#  'reservoir': 112,
#  'depend': 113,
#  'follow': 114,
#  'dur': 115,
#  'hand': 116,
#  'press': 117,
#  '1-14': 118,
#  'oth': 119,
#  'civet': 120,
#  'less': 121,
#  'shown': 122,
#  'fluid': 123,
#  'meas': 124,
#  'abov': 125,
#  'young': 126,
#  'antivir': 127,
#  'coordin': 128,
#  'sars-cov-2': 129,
#  'begin': 130,
#  'wel': 131,
#  'resourc': 132,
#  'problem': 133,
#  'world': 134,
#  'nos': 135,
#  'suspect': 136,
#  'cup': 137,
#  'spee': 138,
#  'clos': 139,
#  'feet': 140,
#  'und': 141,
#  'strain': 142,
#  'old': 143,
#  'liv': 144,
#  'becom': 145,
#  'acut': 146,
#  'infecty': 147,
#  'pre-existing': 148,
#  'qual': 149,
#  'every': 150,
#  'ye': 151,
#  '1': 152,
#  'ceas': 153,
#  'includ': 154,
#  'elbow': 155,
#  'smok': 156,
#  'saf': 157,
#  'glob': 158,
#  'tim': 159,
#  'thorough': 160,
#  'expos': 161,
#  'appear': 162,
#  'hos': 163,
#  'nee': 164,
#  'caes': 165,
#  'breath': 166,
#  'condit': 167,
#  'outbreak': 168,
#  'ther': 169,
#  'study': 170,
#  'nas': 171,
#  'bef': 172,
#  'behav': 173,
#  'effect': 174,
#  'handl': 175,
#  'tel': 176,
#  'theref': 177,
#  'ont': 178,
#  'heal': 179,
#  'hygy': 180,
#  'new': 181,
#  'consid': 182,
#  'gath': 183,
#  'it鈥檚': 184,
#  'hour': 185,
#  'fing': 186,
#  'fec': 187,
#  'rel': 188,
#  'feat': 189,
#  'control': 190,
#  'doe': 191,
#  'hom': 192,
#  'diabet': 193,
#  'effort': 194,
#  'environ': 195,
#  'sur': 196,
#  'dead': 197,
#  'cov': 198,
#  'many': 199,
#  'wuh': 200,
#  'cal': 201,
#  'hajs': 202,
#  'lip': 203,
#  'thes': 204,
#  'consum': 205,
#  'sor': 206,
#  '5': 207,
#  'least': 208,
#  'confirm': 209,
#  'self-isolate': 210,
#  'allevy': 211,
#  'precaut': 212,
#  'vuln': 213,
#  'provid': 214,
#  '-': 215,
#  'away': 216,
#  'baby': 217,
#  'person': 218,
#  'occas': 219,
#  'tru': 220,
#  'ar': 221,
#  'self-medication': 222,
#  'pregn': 223,
#  'unfortun': 224,
#  'wish': 225,
#  'thank': 226,
#  'clin': 227,
#  'undercook': 228,
#  'bad': 229,
#  'perform': 230,
#  'antibiot': 231,
#  'wat': 232,
#  'e.g': 233,
#  'camel': 234,
#  'spreading': 235,
#  'also': 236,
#  'don鈥檛': 237,
#  'breastfee': 238,
#  'immedy': 239,
#  'chronic': 240,
#  'stop': 241,
#  'adv': 242,
#  'lov': 243,
#  'market': 244,
#  'foet': 245,
#  'catch': 246,
#  'runny': 247,
#  'two': 248,
#  'short': 249,
#  'long': 250,
#  'healthc': 251,
#  'facilit': 252,
#  'contact': 253,
#  'ach': 254,
#  'alcohol-based': 255,
#  'report': 256,
#  'count': 257,
#  'period': 258,
#  'western': 259,
#  'increas': 260,
#  'religy': 261,
#  'evid': 262,
#  'point': 263,
#  'develop': 264,
#  'contain': 265,
#  "'m": 266,
#  'certain': 267,
#  'know': 268,
#  'drom': 269,
#  'togeth': 270,
#  'hum': 271,
#  'met': 272,
#  'rub': 273,
#  "n't": 274,
#  'airborn': 275,
#  'wom': 276,
#  'syndrom': 277,
#  'loc': 278,
#  'body': 279,
#  'hang': 280,
#  'congest': 281,
#  'sick': 282,
#  'newborn': 283,
#  'covid-19': 284,
#  'childr': 285,
#  'cant': 286,
#  'commun': 287,
#  'found': 288,
#  'infect': 289,
#  'keep': 290,
#  'simil': 291,
#  'reintroduc': 292,
#  'symptom': 293,
#  'avail': 294,
#  'rememb': 295,
#  'sport': 296,
#  'med': 297,
#  'meat': 298,
#  'flo': 299,
#  'diarrhe': 300,
#  'persist': 301,
#  'dea': 302,
#  'raw': 303,
#  'uncook': 304,
#  'heart': 305,
#  'auth': 306,
#  'surfac': 307,
#  'ident': 308,
#  'sars-cov': 309,
#  'coronavir': 310,
#  'remedy': 311,
#  'sam': 312,
#  'surv': 313,
#  'giv': 314,
#  'vir': 315,
#  'elig': 316,
#  'cat': 317,
#  'investig': 318,
#  'pop': 319,
#  'produc': 320,
#  'caught': 321,
#  'dry': 322,
#  'ord': 323,
#  'mers-cov': 324,
#  'stay': 325,
#  'mak': 326,
#  'difficul': 327,
#  'past': 328,
#  'genet': 329,
#  'speak': 330,
#  'kil': 331,
#  'sery': 332,
#  'rang': 333,
#  '鈥渕ass': 334,
#  'ey': 335,
#  'tobacco': 336,
#  'themselv': 337,
#  'peopl': 338,
#  'exampl': 339,
#  'tri': 340,
#  'transmit': 341,
#  'intend': 342,
#  'hong': 343,
#  'mou': 344,
#  'wast': 345,
#  'headach': 346,
#  'unfold': 347,
#  'beg': 348,
#  'childbir': 349,
#  'commerc': 350,
#  'around': 351,
#  'bent': 352,
#  'simpl': 353,
#  'decemb': 354,
#  'rec': 355,
#  'emerg': 356,
#  'multipl': 357,
#  'individ': 358,
#  'travel': 359,
#  'whil': 360,
#  'asymptom': 361,
#  'gathering鈥': 362,
#  'ear': 363,
#  'without': 364,
#  'import': 365,
#  'soc': 366,
#  '鈥渋ncubation': 367,
#  'amniot': 368,
#  'channel': 369,
#  'sev': 370,
#  'diseas': 371,
#  'someon': 372,
#  'stag': 373,
#  'seek': 374,
#  'receiv': 375,
#  'temp': 376,
#  'unborn': 377,
#  'tak': 378,
#  'maintain': 379,
#  'known': 380,
#  'test': 381,
#  '37.3': 382,
#  'droplet': 383,
#  'wheth': 384,
#  'sourc': 385,
#  'assocy': 386,
#  'gen': 387,
#  'espec': 388,
#  'farm': 389,
#  'way': 390,
#  'licens': 391,
#  'del': 392,
#  'org': 393,
#  'quit': 394,
#  'risk': 395,
#  'wis': 396,
#  'oft': 397,
#  'humid': 398,
#  'fomit': 399,
#  'hotspot': 400,
#  'comfort': 401,
#  'recommend': 402,
#  'avoid': 403,
#  'cur': 404,
#  'medicin': 405,
#  'al': 406,
#  'seem': 407,
#  'yet': 408,
#  'latest': 409,
#  'wil': 410,
#  'phys': 411,
#  'spread': 412,
#  'low': 413,
#  'chang': 414,
#  'influenz': 415,
#  'learn': 416,
#  'feel': 417,
#  'drug': 418,
#  'pip': 419,
#  'estim': 420,
#  'inform': 421,
#  'appoint': 422,
#  'tre': 423,
#  'larg': 424,
#  'may': 425,
#  'could': 426,
#  '3': 427,
#  'init': 428,
#  'help': 429,
#  'wear': 430,
#  'numb': 431,
#  '80': 432,
#  'concern': 433,
#  'prelimin': 434,
#  'blood': 435,
#  'pack': 436,
#  'paty': 437,
#  'andprotect': 438,
#  'determin': 439,
#  'thos': 440,
#  'spec': 441,
#  'anyon': 442,
#  'regul': 443,
#  '20': 444,
#  'bring': 445,
#  'main': 446,
#  'spreads': 447,
#  'mor': 448,
#  'set': 449,
#  'mass': 450,
#  'profil': 451,
#  'virus': 452,
#  'bir': 453,
#  'mort': 454,
#  'incub': 455,
#  'anim': 456,
#  'protocol': 457,
#  'go': 458,
#  'sar': 459,
#  'pain': 460,
#  'support': 461,
#  'involv': 462,
#  'eld': 463,
#  'dispos': 464,
#  'bact': 465,
#  'pandem': 466,
#  'hospit': 467,
#  'act': 468,
#  'rath': 469,
#  'stil': 470,
#  'plac': 471,
#  'wer': 472,
#  'typ': 473,
#  '2019.': 474,
#  'yo': 475,
#  'fac': 476,
#  'delivery': 477,
#  'fal': 478,
#  'car': 479,
#  'smal': 480,
#  'pass': 481,
#  'respir': 482,
#  'sint': 483,
#  'lik': 484,
#  'vary': 485,
#  'system': 486,
#  'lung': 487,
#  'immunosuppress': 488,
#  'visit': 489,
#  'success': 490,
#  'air': 491,
#  'meet': 492,
#  'il': 493,
#  'shar': 494,
#  'gatherings鈥': 495,
#  'cle': 496,
#  'thrive': 497,
#  'routin': 498,
#  'get': 499,
#  'becaus': 500,
#  'mov': 501,
#  'pres': 502,
#  'cancel': 503,
#  'pot': 504,
#  'soap': 505,
#  'vaccin': 506,
#  'upd': 507,
#  'heavy': 508,
#  'intern': 509,
#  'cigaret': 510,
#  'us': 511,
#  '<pad>': 512,
#  '<unk>': 513}

# %% [markdown]
# ### 利用所有文本预训练词向量模型
# 这里使用FastText模型来预训练。

# %%
alltext[:3], len(alltext)
# Out:
# ([['avoid', 'touch', 'ey', 'nos', 'mou'],
#   ['pres', 'ther', 'evid', 'ar', 'high', 'risk', 'sev', 'il', 'gen', 'pop'],
#   ['ar', 'smok', 'tobacco', 'us', 'high', 'risk', 'covid-19', 'infect']],
#  125)

# %% [markdown]
# 解释一下这里使用的FastText模型的参数
# * window：即词向量上下文最大距离，window越大，则和某一词较远的词也会产生上下文关系。默认值为5，在实际使用中，可以根据实际的需求来动态调整这个window的大小。如果是小语料则这个值可以设的更小。我们的实验语料相对较小，用3比较合适。
# * sg：对word2vec两个模型的选择了。如果是0， 则是CBOW模型；是1则是Skip-Gram模型；默认是0即CBOW模型。这里用skip-gram模型来训练。
# * min_count: 词语出现频率小于该数量的会被舍弃。这里取1，没有单词会被舍弃。

# %%
from gensim.models import FastText

model = FastText(window=3, sg=1, min_count=1)
model.build_vocab(alltext)
model.train(alltext, total_examples=model.corpus_count, epochs=model.iter)
model.save('fasttext.model')  # save model
# Out:
# G:\Programmes\Python\Python37\Lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """

# %%
# 词向量实例
model["adult"]
# Out:
# G:\Programmes\Python\Python37\Lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([-6.2693696e-04, -9.8457863e-04,  9.8339701e-04,  1.6925446e-04,
#         1.4094013e-03,  1.8271153e-03, -2.9640394e-04, -1.0704385e-03,
#         1.1594658e-03,  5.7776051e-04,  7.5473665e-04, -9.7423053e-04,
#        -7.4995006e-04,  1.9680714e-04,  1.3524632e-03, -2.6108832e-03,
#         4.6914406e-04, -1.9118749e-03, -2.2244643e-04, -1.1623199e-03,
#        -6.1066344e-04, -5.4314069e-04, -7.4876385e-04,  1.9070458e-03,
#        -8.4244210e-04, -1.1510347e-04, -5.4259732e-04, -5.8793928e-04,
#        -2.6635404e-03, -3.3723423e-03,  6.4604980e-04,  1.5556007e-03,
#        -1.3286719e-03, -1.9271809e-04, -1.4150098e-03,  3.4157922e-03,
#        -8.3717494e-04, -1.0564235e-03,  2.7153147e-03, -1.4211363e-04,
#        -1.1447412e-03, -1.4057418e-03,  7.9186269e-05,  1.2729666e-03,
#         2.0843300e-03, -6.0061464e-04, -7.3077006e-04, -1.3162442e-03,
#        -2.0611386e-03, -2.1279163e-03,  1.1862952e-03,  7.0707341e-05,
#         2.6898419e-03,  2.5865627e-03,  1.1982427e-03, -2.5961166e-03,
#        -5.9573165e-05, -7.6233433e-04, -8.9739828e-04, -1.1744234e-03,
#         4.1819815e-04, -2.7650353e-04, -2.8661848e-03,  9.7262958e-04,
#        -7.6944684e-04,  1.3385343e-03, -1.7676902e-03, -1.2565035e-04,
#        -3.5933856e-04, -5.7256990e-04,  1.9661617e-05,  7.7812449e-04,
#        -2.0281834e-04, -1.8564856e-03, -6.9927401e-04,  1.5068068e-03,
#        -1.0580666e-03,  2.1589725e-04, -3.4542815e-04, -1.8634230e-03,
#        -2.1361778e-03,  2.1125728e-03, -1.0891560e-03, -6.7055260e-04,
#        -2.2739868e-03, -3.0416197e-03,  2.2510439e-03,  3.3018235e-04,
#         1.1044811e-03, -2.0087119e-03,  1.8037956e-03, -1.0461345e-03,
#         4.4293041e-04,  7.7559141e-04,  3.2246764e-05, -1.0361965e-03,
#         1.1576829e-03, -3.2854576e-03, -1.2811559e-04, -3.3235582e-04],
#       dtype=float32)

# %%
if 'hshs' not in model.wv.index2word:
    print('no')
# Out:
# no

# %% [markdown]
# ### 实现QA机器人
# 一般的QA机器人需要预训练一个文本相似度模型，比如ESIM。然而，我们收集到的数据仅仅有问题-答案对，相似/不相似句子对(比如句子1，句子2相似或者不相似)，属于无监督数据，我们难以用深度学习模型训练一个文本相似度模型。
# 对于无监督文本，目前较为常见的方法就是预训练一个词向量模型，将文本通过词向量模型转化为句向量。本次实验采用的方法是将句子通过预训练好的FastText模型得到每个词的词向量，然后以TF-IDF作为权重加和，从而得到句向量。机器人获得了用户的query之后，将query转换为句向量，与问答库中的问题的句向量计算余弦距离，取最高者的答案回复。若余弦距离均不超过  ，则返回“没有该问题”。

# %% [markdown]
# 由于jupyter很难实现交互，因此机器人的主程序在chatbot.py中
